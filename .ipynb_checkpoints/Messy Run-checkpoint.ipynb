# %%
import pandas as pd
import pickle

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

import seaborn as sns

# %%
pd.set_option('display.max_rows', 300)

# %%
survey = pd.read_csv('/Users/williamyee/Documents/Data Bootcamp/Classification-Project-DSjobs/Data/kaggle-survey-2017/multi_r_.csv', encoding = 'ISO-8859-1')
# Out:
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (32,84,87,88,100,110,117,124,125,128,130,131,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
survey.head()
# Out:
#    Unnamed: 0                                       GenderSelect  \
# 0           1  Non-binary, genderqueer, or gender non-conforming
# 1           2                                             Female
# 2           3                                               Male
# 3           4                                               Male
# 4           5                                               Male
#
#          Country   Age                                   EmploymentStatus  \
# 0            NaN   NaN                                 Employed full-time
# 1  United States  30.0                 Not employed, but looking for work
# 2         Canada  28.0                 Not employed, but looking for work
# 3  United States  56.0  Independent contractor, freelancer, or self-em...
# 4         Taiwan  38.0                                 Employed full-time
#
#   StudentStatus LearningDataScience CodeWriter CareerSwitcher  \
# 0           NaN                 NaN        Yes            NaN
# ...

# %%
survey.EmploymentStatus.unique()
# Out:
# array(['Employed full-time', 'Not employed, but looking for work',
#        'Independent contractor, freelancer, or self-employed',
#        'Not employed, and not looking for work', 'Employed part-time',
#        'Retired', 'I prefer not to say'], dtype=object)

# %%
survey.groupby('EmploymentStatus').count()
# Out:
#                                                     Unnamed: 0  GenderSelect  \
# EmploymentStatus
# Employed full-time                                       10897         10853
# Employed part-time                                         917           910
# I prefer not to say                                        420           404
# Independent contractor, freelancer, or self-emp...        1330          1321
# Not employed, and not looking for work                     924           919
# Not employed, but looking for work                        2110          2098
# Retired                                                    118           116
#
#                                                     Country    Age  \
# EmploymentStatus
# Employed full-time                                    10840  10702
# Employed part-time                                      907    901
# I prefer not to say                                     399    382
# ...

# %%
survey.UniversityImportance.value_counts()
# Out:
# Very important                                 2925
# Important                                      2347
# Somewhat important                             1695
# Not very important                              772
# Not at all important                            317
# N/A, I did not receive any formal education      42
# Name: UniversityImportance, dtype: int64

# %%
survey.TitleFit.value_counts()
# Out:
# Fine         7501
# Perfectly    2305
# Poorly       1698
# Name: TitleFit, dtype: int64

# %%
survey.GenderSelect.value_counts()
# Out:
# Male                                                 13610
# Female                                                2778
# A different identity                                   159
# Non-binary, genderqueer, or gender non-conforming       74
# Name: GenderSelect, dtype: int64

# %%
survey.EmploymentStatus.value_counts()
# Out:
# Employed full-time                                      10897
# Not employed, but looking for work                       2110
# Independent contractor, freelancer, or self-employed     1330
# Not employed, and not looking for work                    924
# Employed part-time                                        917
# I prefer not to say                                       420
# Retired                                                   118
# Name: EmploymentStatus, dtype: int64

# %%
survey.CareerSwitcher.value_counts()
# Out:
# Yes    2126
# No      886
# Name: CareerSwitcher, dtype: int64

# %%
survey.CurrentEmployerType.value_counts()
# Out:
# Employed by professional services/consulting firm                                                                                                                                                                                                                                                                                        2383
# Employed by a company that performs advanced analytics                                                                                                                                                                                                                                                                                   2240
# ...

# %%
survey.Tenure.value_counts()
# Out:
# 1 to 2 years                          3424
# 3 to 5 years                          3355
# Less than a year                      2380
# More than 10 years                    2028
# 6 to 10 years                         1714
# I don't write code to analyze data     631
# Name: Tenure, dtype: int64

# %%
list(freeform.columns.values)
# Out:
# ['GenderFreeForm',
#  'KaggleMotivationFreeForm',
#  'CurrentJobTitleFreeForm',
#  'MLToolNextYearFreeForm',
#  'MLMethodNextYearFreeForm',
#  'LanguageRecommendationFreeForm',
#  'PublicDatasetsFreeForm',
#  'PersonalProjectsChallengeFreeForm',
#  'LearningPlatformCommunityFreeForm',
#  'LearningPlatformFreeForm1',
#  'LearningPlatformFreeForm2',
#  'LearningPlatformFreeForm3',
#  'LearningPlatformUsefulnessCommunitiesFreeForm',
#  'LearningPlatformUsefulnessFreeForm1Select',
#  'LearningPlatformUsefulnessFreeForm1SelectFreeForm',
#  'LearningPlatformUsefulnessFreeForm2Select',
#  'LearningPlatformUsefulnessFreeForm2SelectFreeForm',
#  'LearningPlatformUsefulnessFreeForm3Select',
#  'LearningPlatformUsefulnessFreeForm3SelectFreeForm',
#  'BlogsPodcastsNewslettersFreeForm',
#  'JobSkillImportanceOtherSelect1FreeForm',
#  'JobSkillImportanceOtherSelect2FreeForm',
#  'JobSkillImportanceOtherSelect3FreeForm',
#  'CoursePlatformFreeForm',
#  'HardwarePersonalProjectsFreeForm',
# ...

# %%
survey.LearningDataScienceTime.value_counts()
# Out:
# < 1 year       2093
# 1-2 years      1566
# 3-5 years       540
# 5-10 years      106
# 15+ years        30
# 10-15 years      14
# Name: LearningDataScienceTime, dtype: int64

# %%
survey.CurrentJobTitleSelect.value_counts()
# Out:
# Data Scientist                          2433
# Software Developer/Software Engineer    1759
# Other                                   1233
# Data Analyst                            1213
# Scientist/Researcher                     978
# Business Analyst                         796
# Researcher                               619
# Machine Learning Engineer                617
# Engineer                                 552
# Programmer                               462
# Computer Scientist                       335
# Statistician                             289
# DBA/Database Engineer                    187
# Predictive Modeler                       181
# Data Miner                               118
# Operations Research Practitioner          58
# Name: CurrentJobTitleSelect, dtype: int64

# %%
survey.StudentStatus.value_counts()
# Out:
# Yes    981
# No     299
# Name: StudentStatus, dtype: int64

# %%
survey = survey[survey.UniversityImportance.isnull()]
survey.shape
# Out:
# (8618, 229)

# %%
percent_missing = survey.isnull().sum()*100/len(survey)
missing_value_df = pd.DataFrame({'columnname':survey.columns, 'percent_missing':percent_missing})
seventy_five_data = missing_value_df[missing_value_df.percent_missing<100]

# %%
seventy_five_data
# Out:
#                                                                               columnname  \
# Unnamed: 0                                                                    Unnamed: 0
# GenderSelect                                                                GenderSelect
# Country                                                                          Country
# Age                                                                                  Age
# EmploymentStatus                                                        EmploymentStatus
# StudentStatus                                                              StudentStatus
# LearningDataScience                                                  LearningDataScience
# CodeWriter                                                                    CodeWriter
# CareerSwitcher                                                            CareerSwitcher
# ...

# %%
survey.LearningCategoryKaggle.value_counts()
# Out:
# 0.0      8446
# 10.0     1580
# 5.0      1048
# 20.0      738
# 30.0      306
# 15.0      221
# 25.0      144
# 50.0      127
# 40.0      124
# 2.0        91
# 1.0        87
# 3.0        29
# 35.0       26
# 70.0       26
# 60.0       24
# 80.0       18
# 100.0      12
# 45.0       10
# 4.0        10
# 8.0         8
# 90.0        5
# 33.0        5
# 7.0         4
# 6.0         3
# 55.0        3
# 14.0        3
# 75.0        3
# 34.0        2
# 18.0        2
# 13.0        2
# 19.0        2
# 17.0        2
# 9.0         2
# 16.0        1
# 95.0        1
# 12.0        1
# 22.0        1
# 2.5         1
# 24.0        1
# 0.1         1
# 11.0        1
# 12.5        1
# 65.0        1
# 62.0        1
# 7.5         1
# 38.0        1
# Name: LearningCategoryKaggle, dtype: int64

# %%
survey_minimal_missing= survey[list(seventy_five_data.columnname)]
x = survey_minimal_missing.drop(columns = '')

# %%
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
X_imputed

# %%
# Out:
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/lib/function_base.py:747: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= mn)
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/lib/function_base.py:748: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= mx)

# %%
enc = OneHotEncoder(handle_unknown= 'ignore')
y = enc.fit_transform(y)
X = enc.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-3b69fdebe8bd> in <module>
#       1 enc = OneHotEncoder(handle_unknown= 'ignore')
# ----> 2 y = enc.fit_transform(y)
#       3 X = enc.fit_transform(X)
#
# NameError: name 'y' is not defined

# %%
X, X_test, y, y_test = train_test_split(X, y, test_size=.2, random_state=100)

# %%
clf = RandomForestClassifier(n_estimators=100, max_depth=2,random_state=0)
clf.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-ebfa879f4f7e> in <module>
#       1 clf = RandomForestClassifier(n_estimators=100, max_depth=2,random_state=0)
# ----> 2 clf.fit(X,y)
#
# NameError: name 'X' is not defined
